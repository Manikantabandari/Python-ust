# %%
import os
os.mkdir('ram')

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Administrator'

# %%
lst = open('ram.txt','w')
lst.write('Hello how r you')
lst.close()

# %%
lst = open('ram.txt','r')
lst.read()
# Out:
# 'Hello how r you'

# %%
lst.close()
