# %%
lst = open('C:/Users/Administrator/Desktop/file')
lst.close
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 lst = open('C:/Users/Administrator/Desktop/file')
#       2 lst.close
#
# File C:\Program Files\Python312\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/Administrator/Desktop/file'

# %%
os.getenv("Home")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 os.getenv("Home")
#
# NameError: name 'os' is not defined

# %%
import os
os.getenv("Home")

# %%
import os

os.getenv("/users/Administrator") # home directory
lst=open("my3.txt","w") # create a file on home directory
lst.write("this is 1st module2 \n") # tis will write 1st line of file
lst.write("This is 2nd module")
lst.close()

# %%
lst=open("my3.txt","r")
lst.read()
# Out:
# 'this is 1st module2 \nThis is 2nd module'

# %%
str = "mani"
part1 = str[0:3]

# %%
lst=open("my3.txt","r")
lst.read(4) # pointer will start reading from t
# Out:
# 'this'

# %%
lst=open("my3.txt","r")
lst.read(8)
# Out:
# 'this is '

# %%
lst.tell() # it will tell your  position
# Out:
# 8

# %%
lst.seek(5) # it will set agin pointer position to initail position
# Out:
# 5

# %%
print(lst.read())
# Out:
# is 1st module2
# This is 2nd module

# %%
lst.seek(0)
for line in lst:
    print(line)
# Out:
# this is 1st module2
#
# This is 2nd module

# %%
import os
os.rename("my3.txt","mani.txt")

# %%
import os
os.getcwd() # to get the current directory
# Out:
# 'C:\\Users\\Administrator'

# %%
os.chdir("C:\\Users\\Administrator\\Desktop")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\Desktop'

# %%
os.mkdir('abhi') # create new directory

# %%
os.listdir(os.getcwd())
# Out:
# ['abhi',
#  'desktop.ini',
#  'file.txt',
#  'Microsoft Edge.lnk',
#  'MongoDBCompass.lnk',
#  'Readme - Shortcut.lnk']

# %%
import os
os.getenv("home")

# %%
example.add(78,67)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 example.add(78,67)
#
# NameError: name 'example' is not defined

# %%
import math
print(math.pi)
# Out:
# 3.141592653589793

# %%
import datetime as dt
dt.datetime.now()
# Out:
# datetime.datetime(2026, 2, 20, 9, 16, 9, 992737)

# %%
import math as m
print(m.pi)
# Out:
# 3.141592653589793

# %%
from datetime import datetime
datetime.now()
# Out:
# datetime.datetime(2026, 2, 20, 9, 17, 5, 783384)
